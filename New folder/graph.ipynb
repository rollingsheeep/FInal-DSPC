# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\user\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\user\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\user\anaconda3\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\user\anaconda3\lib\site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import os
import subprocess
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from struct import unpack

# First, change to the parent directory if we're in the exe directory
current_dir = os.getcwd()
if current_dir.endswith('exe'):
    os.chdir('..')
    current_dir = os.getcwd()

def get_bmp_bit_depth(file_path):
    try:
        with open(file_path, 'rb') as f:
            # Read BMP header
            f.seek(0)
            header = f.read(54)
            # Check if it's a BMP file
            if header[0:2] != b'BM':
                return None
            # Get bit depth (offset 28)
            bit_depth = unpack('H', header[28:30])[0]
            return bit_depth
    except Exception as e:
        print(f"Error reading BMP header for {file_path}: {e}")
        return None

def process_image(input_file, method, exe_name):
    try:
        # Get absolute paths
        current_dir = os.getcwd()
        input_path = os.path.abspath(os.path.join(current_dir, "input", input_file))
        output_dir = os.path.abspath(os.path.join(current_dir, "output"))
        exe_dir = os.path.abspath(os.path.join(current_dir, "exe"))
        
        # Check if input file exists and is 24-bit BMP
        if not os.path.exists(input_path):
            print(f"Input file not found: {input_path}")
            return None
            
        bit_depth = get_bmp_bit_depth(input_path)
        if bit_depth != 24:
            print(f"Skipping {input_file} (not a 24-bit BMP, found {bit_depth}-bit)")
            return None
            
        # Get the base name of the input file
        name_without_ext = os.path.splitext(input_file)[0]
        
        # Create output directory if it doesn't exist
        os.makedirs(output_dir, exist_ok=True)
        
        # Change to exe directory
        os.chdir(exe_dir)
        
        # Construct the command with absolute paths
        cmd = [
            f"./{exe_name}",
            input_path,
            os.path.join(output_dir, f"Result{name_without_ext}.bmp"),
            method
        ]
        
        print(f"Processing {input_file} ({bit_depth}-bit) using {method} method...")
        print(f"Command: {' '.join(cmd)}")
        
        # Run the command and capture output
        result = subprocess.run(cmd, 
                              check=True, 
                              capture_output=True, 
                              text=True,
                              encoding='utf-8')
        
        # Print the full output for debugging
        print("Output:", result.stdout)
        print("OhYESDADDY:", result.stderr)
        
        # Change back to original directory
        os.chdir(current_dir)
        
        # Extract execution time from output
        if result.stdout:
            for line in result.stdout.split('\n'):
                if "Processing completed in" in line:
                    try:
                        # Extract time value
                        time_str = line.split("Processing completed in")[1].split("ms")[0].strip()
                        time_ms = int(time_str)
                        print(f"Execution time: {time_ms} ms")
                        return time_ms
                    except Exception as e:
                        print(f"Error parsing time from output: {e}")
                        print(f"Line was: {line}")
        
        print("Warning: Could not find execution time in output")
        return None
                
    except subprocess.CalledProcessError as e:
        print(f"Error processing {input_file} with {method}: {e}")
        print(f"Command output: {e.output}")
        print(f"Command stderr: {e.stderr}")
        if os.getcwd() != current_dir:
            os.chdir(current_dir)
        return None
    except Exception as e:
        print(f"Error processing {input_file} with {method}: {e}")
        if os.getcwd() != current_dir:
            os.chdir(current_dir)
        return None

def main():
    # Print current working directory
    print(f"Current working directory: {os.getcwd()}")
    
    # Dictionary mapping methods to their executable names with correct method parameters
    method_exes = {
        "sequential": "sequential.exe",
        "omp": "omp_version.exe",
        "mpi": "mpi_version.exe",
        "cuda": "cuda_version.exe"
    }
    
    # Method display names for graphs and statistics
    method_display_names = {
        "sequential": "Sequential",
        "omp": "OpenMP",
        "mpi": "MPI",
        "cuda": "CUDA"
    }
    
    # Verify directories exist
    input_dir = os.path.abspath("input")
    if not os.path.exists(input_dir):
        print(f"Error: Input directory not found at {input_dir}")
        return
        
    # Get list of BMP files and check bit depth
    input_files = []
    print("\nChecking BMP files:")
    for f in os.listdir(input_dir):
        if f.lower().endswith('.bmp'):
            file_path = os.path.join(input_dir, f)
            bit_depth = get_bmp_bit_depth(file_path)
            print(f"{f}: {bit_depth}-bit")
            if bit_depth == 24:
                input_files.append(f)
    
    print(f"\nFound {len(input_files)} compatible 24-bit BMP files out of {len([f for f in os.listdir(input_dir) if f.lower().endswith('.bmp')])} total BMP files")
    
    # Create DataFrame to store results
    results = []
    
    # Process each compatible file with each method
    for input_file in input_files:
        input_path = os.path.join(input_dir, input_file)
        file_size = os.path.getsize(input_path) / (1024 * 1024)  # Size in MB
        
        for method, exe_name in method_exes.items():
            execution_time = process_image(input_file, method, exe_name)
            if execution_time is not None:
                results.append({
                    'File': input_file,
                    'Method': method_display_names[method],
                    'Time (ms)': execution_time,
                    'Size (MB)': file_size
                })
    
    if not results:
        print("No results to analyze!")
        return
        
    # Create DataFrame
    df = pd.DataFrame(results)
    
    # Create plots
    plt.style.use('seaborn-v0_8')
    
    # 1. Box plot
    plt.figure(figsize=(12, 6))
    sns.boxplot(x='Method', y='Time (ms)', data=df)
    plt.title('Execution Time Distribution by Method')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig('boxplot_comparison.png')
    plt.close()
    
    # 2. Violin plot
    plt.figure(figsize=(12, 6))
    sns.violinplot(x='Method', y='Time (ms)', data=df)
    plt.title('Execution Time Distribution (Violin Plot)')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig('violin_comparison.png')
    plt.close()
    
    # 3. Scatter plot
    plt.figure(figsize=(12, 6))
    for method in method_display_names.values():
        method_data = df[df['Method'] == method]
        plt.scatter(method_data['Size (MB)'], method_data['Time (ms)'], label=method, alpha=0.6)
    plt.xlabel('File Size (MB)')
    plt.ylabel('Execution Time (ms)')
    plt.title('Execution Time vs File Size')
    plt.legend()
    plt.tight_layout()
    plt.savefig('size_vs_time.png')
    plt.close()
    
    # 4. Bar plot
    plt.figure(figsize=(12, 6))
    avg_times = df.groupby('Method')['Time (ms)'].mean()
    avg_times.plot(kind='bar')
    plt.title('Average Execution Time by Method')
    plt.ylabel('Average Time (ms)')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig('average_times.png')
    plt.close()
    
    # Print statistics with more detail
    print("\nPerformance Statistics:")
    print("=" * 50)
    
    # Group by Method and calculate statistics
    stats = df.groupby('Method').agg({
        'Time (ms)': ['count', 'mean', 'median', 'std', 'min', 'max']
    }).round(2)
    
    print("\nDetailed Statistics:")
    print(stats)
    
    # Calculate and print speedup for each file size category
    print("\nSpeedup Analysis:")
    print("=" * 50)
    
    # Create file size categories
    df['Size Category'] = pd.cut(df['Size (MB)'], 
                                bins=[0, 1, 5, 10, float('inf')],
                                labels=['Small (<1MB)', 'Medium (1-5MB)', 'Large (5-10MB)', 'Very Large (>10MB)'])
    
    # Calculate speedup by size category
    for size_cat in df['Size Category'].unique():
        size_data = df[df['Size Category'] == size_cat]
        if len(size_data) > 0:
            print(f"\nSize Category: {size_cat}")
            seq_mean = size_data[size_data['Method'] == 'Sequential']['Time (ms)'].mean()
            for method in method_display_names.values():
                if method != 'Sequential':
                    method_mean = size_data[size_data['Method'] == method]['Time (ms)'].mean()
                    if method_mean > 0:
                        speedup = seq_mean / method_mean
                        print(f"{method}: {speedup:.2f}x speedup")
    
    # Save detailed results
    df.to_csv('performance_results.csv', index=False)
    stats.to_csv('performance_statistics.csv')
    
    print("\nResults and statistics saved to:")
    print("- performance_results.csv")
    print("- performance_statistics.csv")
    print("- boxplot_comparison.png")
    print("- violin_comparison.png")
    print("- size_vs_time.png")
    print("- average_times.png")

if __name__ == "__main__":
    main()
# Out:
# Current working directory: c:\Users\user\Desktop\FInal DSPC\New folder
#
# Checking BMP files:
# 1.bmp: 24-bit
# 10.bmp: 32-bit
# 11.bmp: 24-bit
# 12.bmp: 24-bit
# 13.bmp: 24-bit
# 14.bmp: 24-bit
# 15.bmp: 24-bit
# 16.bmp: 24-bit
# 17.bmp: 24-bit
# 18.bmp: 32-bit
# 19.bmp: 24-bit
# 2.bmp: 24-bit
# 20.bmp: 24-bit
# 21.bmp: 24-bit
# 22.bmp: 24-bit
# 23.bmp: 24-bit
# 24.bmp: 24-bit
# 25.bmp: 24-bit
# 26.bmp: 24-bit
# 27.bmp: 24-bit
# 28.bmp: 24-bit
# 29.bmp: 24-bit
# 3.bmp: 24-bit
# 30.bmp: 24-bit
# 31.bmp: 24-bit
# 32.bmp: 24-bit
# 33.bmp: 24-bit
# 34.bmp: 24-bit
# 35.bmp: 24-bit
# 36.bmp: 24-bit
# 37.bmp: 24-bit
# 38.bmp: 24-bit
# 39.bmp: 24-bit
# 4.bmp: 24-bit
# 40.bmp: 24-bit
# 41.bmp: None-bit
# 42.bmp: 24-bit
# 43.bmp: 24-bit
# 44.bmp: 24-bit
# 45.bmp: 24-bit
# 46.bmp: 24-bit
# 47.bmp: 24-bit
# 48.bmp: 24-bit
# 49.bmp: 24-bit
# 5.bmp: 24-bit
# 50.bmp: 24-bit
# 6.bmp: 24-bit
# 7.bmp: 32-bit
# 8.bmp: 24-bit
# 9.bmp: 24-bit
# sample1.bmp: 24-bit
#
# Found 47 compatible 24-bit BMP files out of 51 total BMP files
# Processing 1.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\1.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result1.bmp sequential
# Output: Processing completed in 15889 ms using sequential method
#
# OhYESDADDY:
# Execution time: 15889 ms
# Processing 1.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\1.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result1.bmp omp
# Output: Processing completed in 1921 ms using omp method
#
# OhYESDADDY:
# Execution time: 1921 ms
# Processing 1.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\1.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result1.bmp mpi
# Output: Processing completed in 4245 ms using mpi method
#
# OhYESDADDY:
# Execution time: 4245 ms
# Processing 1.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\1.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result1.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 2848x4272
# Required memory: 104 MB
# Allocating device memory...
# Allocated input memory: 34 MB
# Allocated blurred memory: 34 MB
# Allocated output memory: 34 MB
# Processing completed in 1773 ms using cuda method
#
# OhYESDADDY:
# Execution time: 1773 ms
# Processing 11.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\11.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result11.bmp sequential
# Output: Processing completed in 1197 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1197 ms
# Processing 11.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\11.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result11.bmp omp
# Output: Processing completed in 33 ms using omp method
#
# OhYESDADDY:
# Execution time: 33 ms
# Processing 11.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\11.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result11.bmp mpi
# Output: Processing completed in 57 ms using mpi method
#
# OhYESDADDY:
# Execution time: 57 ms
# Processing 11.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\11.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result11.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 512x320
# Required memory: 1 MB
# Allocating device memory...
# Allocated input memory: 0 MB
# Allocated blurred memory: 0 MB
# Allocated output memory: 0 MB
# Processing completed in 104 ms using cuda method
#
# OhYESDADDY:
# Execution time: 104 ms
# Processing 12.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\12.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result12.bmp sequential
# Output: Processing completed in 2732 ms using sequential method
#
# OhYESDADDY:
# Execution time: 2732 ms
# Processing 12.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\12.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result12.bmp omp
# Output: Processing completed in 259 ms using omp method
#
# OhYESDADDY:
# Execution time: 259 ms
# Processing 12.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\12.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result12.bmp mpi
# Output: Processing completed in 517 ms using mpi method
#
# OhYESDADDY:
# Execution time: 517 ms
# Processing 12.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\12.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result12.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 1500x966
# Required memory: 12 MB
# Allocating device memory...
# Allocated input memory: 4 MB
# Allocated blurred memory: 4 MB
# Allocated output memory: 4 MB
# Processing completed in 295 ms using cuda method
#
# OhYESDADDY:
# Execution time: 295 ms
# Processing 13.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\13.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result13.bmp sequential
# Output: Processing completed in 1695 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1695 ms
# Processing 13.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\13.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result13.bmp omp
# Output: Processing completed in 117 ms using omp method
#
# OhYESDADDY:
# Execution time: 117 ms
# Processing 13.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\13.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result13.bmp mpi
# Output: Processing completed in 206 ms using mpi method
#
# OhYESDADDY:
# Execution time: 206 ms
# Processing 13.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\13.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result13.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 1024x576
# Required memory: 5 MB
# Allocating device memory...
# Allocated input memory: 1 MB
# Allocated blurred memory: 1 MB
# Allocated output memory: 1 MB
# Processing completed in 147 ms using cuda method
#
# OhYESDADDY:
# Execution time: 147 ms
# Processing 14.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\14.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result14.bmp sequential
# Output: Processing completed in 1805 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1805 ms
# Processing 14.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\14.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result14.bmp omp
# Output: Processing completed in 125 ms using omp method
#
# OhYESDADDY:
# Execution time: 125 ms
# Processing 14.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\14.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result14.bmp mpi
# Output: Processing completed in 238 ms using mpi method
#
# OhYESDADDY:
# Execution time: 238 ms
# Processing 14.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\14.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result14.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 736x920
# Required memory: 5 MB
# Allocating device memory...
# Allocated input memory: 1 MB
# Allocated blurred memory: 1 MB
# Allocated output memory: 1 MB
# Processing completed in 162 ms using cuda method
#
# OhYESDADDY:
# Execution time: 162 ms
# Processing 15.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\15.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result15.bmp sequential
# Output: Processing completed in 2082 ms using sequential method
#
# OhYESDADDY:
# Execution time: 2082 ms
# Processing 15.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\15.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result15.bmp omp
# Output: Processing completed in 209 ms using omp method
#
# OhYESDADDY:
# Execution time: 209 ms
# Processing 15.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\15.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result15.bmp mpi
# Output: Processing completed in 330 ms using mpi method
#
# OhYESDADDY:
# Execution time: 330 ms
# Processing 15.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\15.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result15.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 1100x825
# Required memory: 7 MB
# Allocating device memory...
# Allocated input memory: 2 MB
# Allocated blurred memory: 2 MB
# Allocated output memory: 2 MB
# Processing completed in 219 ms using cuda method
#
# OhYESDADDY:
# Execution time: 219 ms
# Processing 16.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\16.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result16.bmp sequential
# Output: Processing completed in 1367 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1367 ms
# Processing 16.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\16.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result16.bmp omp
# Output: Processing completed in 55 ms using omp method
#
# OhYESDADDY:
# Execution time: 55 ms
# Processing 16.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\16.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result16.bmp mpi
# Output: Processing completed in 106 ms using mpi method
#
# OhYESDADDY:
# Execution time: 106 ms
# Processing 16.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\16.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result16.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 734x413
# Required memory: 2 MB
# Allocating device memory...
# Allocated input memory: 0 MB
# Allocated blurred memory: 0 MB
# Allocated output memory: 0 MB
# Processing completed in 115 ms using cuda method
#
# OhYESDADDY:
# Execution time: 115 ms
# Processing 17.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\17.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result17.bmp sequential
# Output: Processing completed in 3027 ms using sequential method
#
# OhYESDADDY:
# Execution time: 3027 ms
# Processing 17.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\17.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result17.bmp omp
# Output: Processing completed in 301 ms using omp method
#
# OhYESDADDY:
# Execution time: 301 ms
# Processing 17.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\17.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result17.bmp mpi
# Output: Processing completed in 595 ms using mpi method
#
# OhYESDADDY:
# Execution time: 595 ms
# Processing 17.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\17.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result17.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 1749x980
# Required memory: 14 MB
# Allocating device memory...
# Allocated input memory: 4 MB
# Allocated blurred memory: 4 MB
# Allocated output memory: 4 MB
# Processing completed in 315 ms using cuda method
#
# OhYESDADDY:
# Execution time: 315 ms
# Processing 19.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\19.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result19.bmp sequential
# Output: Processing completed in 15114 ms using sequential method
#
# OhYESDADDY:
# Execution time: 15114 ms
# Processing 19.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\19.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result19.bmp omp
# Output: Processing completed in 1911 ms using omp method
#
# OhYESDADDY:
# Execution time: 1911 ms
# Processing 19.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\19.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result19.bmp mpi
# Output: Processing completed in 4203 ms using mpi method
#
# OhYESDADDY:
# Execution time: 4203 ms
# Processing 19.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\19.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result19.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 2832x4256
# Required memory: 103 MB
# Allocating device memory...
# Allocated input memory: 34 MB
# Allocated blurred memory: 34 MB
# Allocated output memory: 34 MB
# Processing completed in 1738 ms using cuda method
#
# OhYESDADDY:
# Execution time: 1738 ms
# Processing 2.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\2.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result2.bmp sequential
# Output: Processing completed in 1258 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1258 ms
# Processing 2.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\2.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result2.bmp omp
# Output: Processing completed in 42 ms using omp method
#
# OhYESDADDY:
# Execution time: 42 ms
# Processing 2.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\2.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result2.bmp mpi
# Output: Processing completed in 77 ms using mpi method
#
# OhYESDADDY:
# Execution time: 77 ms
# Processing 2.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\2.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result2.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 400x550
# Required memory: 1 MB
# Allocating device memory...
# Allocated input memory: 0 MB
# Allocated blurred memory: 0 MB
# Allocated output memory: 0 MB
# Processing completed in 108 ms using cuda method
#
# OhYESDADDY:
# Execution time: 108 ms
# Processing 20.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\20.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result20.bmp sequential
# Output: Processing completed in 1787 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1787 ms
# Processing 20.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\20.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result20.bmp omp
# Output: Processing completed in 125 ms using omp method
#
# OhYESDADDY:
# Execution time: 125 ms
# Processing 20.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\20.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result20.bmp mpi
# Output: Processing completed in 253 ms using mpi method
#
# OhYESDADDY:
# Execution time: 253 ms
# Processing 20.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\20.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result20.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 1000x667
# Required memory: 5 MB
# Allocating device memory...
# Allocated input memory: 1 MB
# Allocated blurred memory: 1 MB
# Allocated output memory: 1 MB
# Processing completed in 167 ms using cuda method
#
# OhYESDADDY:
# Execution time: 167 ms
# Processing 21.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\21.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result21.bmp sequential
# Output: Processing completed in 1802 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1802 ms
# Processing 21.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\21.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result21.bmp omp
# Output: Processing completed in 122 ms using omp method
#
# OhYESDADDY:
# Execution time: 122 ms
# Processing 21.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\21.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result21.bmp mpi
# Output: Processing completed in 232 ms using mpi method
#
# OhYESDADDY:
# Execution time: 232 ms
# Processing 21.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\21.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result21.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 1000x664
# Required memory: 5 MB
# Allocating device memory...
# Allocated input memory: 1 MB
# Allocated blurred memory: 1 MB
# Allocated output memory: 1 MB
# Processing completed in 174 ms using cuda method
#
# OhYESDADDY:
# Execution time: 174 ms
# Processing 22.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\22.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result22.bmp sequential
# Output: Processing completed in 1193 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1193 ms
# Processing 22.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\22.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result22.bmp omp
# Output: Processing completed in 29 ms using omp method
#
# OhYESDADDY:
# Execution time: 29 ms
# Processing 22.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\22.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result22.bmp mpi
# Output: Processing completed in 56 ms using mpi method
#
# OhYESDADDY:
# Execution time: 56 ms
# Processing 22.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\22.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result22.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 500x332
# Required memory: 1 MB
# Allocating device memory...
# Allocated input memory: 0 MB
# Allocated blurred memory: 0 MB
# Allocated output memory: 0 MB
# Processing completed in 86 ms using cuda method
#
# OhYESDADDY:
# Execution time: 86 ms
# Processing 23.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\23.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result23.bmp sequential
# Output: Processing completed in 2044 ms using sequential method
#
# OhYESDADDY:
# Execution time: 2044 ms
# Processing 23.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\23.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result23.bmp omp
# Output: Processing completed in 164 ms using omp method
#
# OhYESDADDY:
# Execution time: 164 ms
# Processing 23.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\23.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result23.bmp mpi
# Output: Processing completed in 309 ms using mpi method
#
# OhYESDADDY:
# Execution time: 309 ms
# Processing 23.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\23.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result23.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 1140x780
# Required memory: 7 MB
# Allocating device memory...
# Allocated input memory: 2 MB
# Allocated blurred memory: 2 MB
# Allocated output memory: 2 MB
# Processing completed in 194 ms using cuda method
#
# OhYESDADDY:
# Execution time: 194 ms
# Processing 24.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\24.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result24.bmp sequential
# Output: Processing completed in 5944 ms using sequential method
#
# OhYESDADDY:
# Execution time: 5944 ms
# Processing 24.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\24.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result24.bmp omp
# Output: Processing completed in 693 ms using omp method
#
# OhYESDADDY:
# Execution time: 693 ms
# Processing 24.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\24.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result24.bmp mpi
# Output: Processing completed in 1494 ms using mpi method
#
# OhYESDADDY:
# Execution time: 1494 ms
# Processing 24.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\24.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result24.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 2560x1706
# Required memory: 37 MB
# Allocating device memory...
# Allocated input memory: 12 MB
# Allocated blurred memory: 12 MB
# Allocated output memory: 12 MB
# Processing completed in 667 ms using cuda method
#
# OhYESDADDY:
# Execution time: 667 ms
# Processing 25.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\25.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result25.bmp sequential
# Output: Processing completed in 1329 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1329 ms
# Processing 25.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\25.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result25.bmp omp
# Output: Processing completed in 51 ms using omp method
#
# OhYESDADDY:
# Execution time: 51 ms
# Processing 25.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\25.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result25.bmp mpi
# Output: Processing completed in 96 ms using mpi method
#
# OhYESDADDY:
# Execution time: 96 ms
# Processing 25.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\25.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result25.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 690x402
# Required memory: 2 MB
# Allocating device memory...
# Allocated input memory: 0 MB
# Allocated blurred memory: 0 MB
# Allocated output memory: 0 MB
# Processing completed in 101 ms using cuda method
#
# OhYESDADDY:
# Execution time: 101 ms
# Processing 26.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\26.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result26.bmp sequential
# Output: Processing completed in 5594 ms using sequential method
#
# OhYESDADDY:
# Execution time: 5594 ms
# Processing 26.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\26.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result26.bmp omp
# Output: Processing completed in 608 ms using omp method
#
# OhYESDADDY:
# Execution time: 608 ms
# Processing 26.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\26.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result26.bmp mpi
# Output: Processing completed in 1360 ms using mpi method
#
# OhYESDADDY:
# Execution time: 1360 ms
# Processing 26.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\26.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result26.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 2500x1656
# Required memory: 35 MB
# Allocating device memory...
# Allocated input memory: 11 MB
# Allocated blurred memory: 11 MB
# Allocated output memory: 11 MB
# Processing completed in 560 ms using cuda method
#
# OhYESDADDY:
# Execution time: 560 ms
# Processing 27.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\27.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result27.bmp sequential
# Output: Processing completed in 1404 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1404 ms
# Processing 27.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\27.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result27.bmp omp
# Output: Processing completed in 61 ms using omp method
#
# OhYESDADDY:
# Execution time: 61 ms
# Processing 27.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\27.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result27.bmp mpi
# Output: Processing completed in 117 ms using mpi method
#
# OhYESDADDY:
# Execution time: 117 ms
# Processing 27.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\27.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result27.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 670x504
# Required memory: 2 MB
# Allocating device memory...
# Allocated input memory: 0 MB
# Allocated blurred memory: 0 MB
# Allocated output memory: 0 MB
# Processing completed in 110 ms using cuda method
#
# OhYESDADDY:
# Execution time: 110 ms
# Processing 28.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\28.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result28.bmp sequential
# Output: Processing completed in 1065 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1065 ms
# Processing 28.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\28.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result28.bmp omp
# Output: Processing completed in 10 ms using omp method
#
# OhYESDADDY:
# Execution time: 10 ms
# Processing 28.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\28.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result28.bmp mpi
# Output: Processing completed in 17 ms using mpi method
#
# OhYESDADDY:
# Execution time: 17 ms
# Processing 28.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\28.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result28.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 355x142
# Required memory: 0 MB
# Allocating device memory...
# Allocated input memory: 0 MB
# Allocated blurred memory: 0 MB
# Allocated output memory: 0 MB
# Processing completed in 73 ms using cuda method
#
# OhYESDADDY:
# Execution time: 73 ms
# Processing 29.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\29.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result29.bmp sequential
# Output: Processing completed in 11848 ms using sequential method
#
# OhYESDADDY:
# Execution time: 11848 ms
# Processing 29.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\29.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result29.bmp omp
# Output: Processing completed in 1457 ms using omp method
#
# OhYESDADDY:
# Execution time: 1457 ms
# Processing 29.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\29.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result29.bmp mpi
# Output: Processing completed in 3290 ms using mpi method
#
# OhYESDADDY:
# Execution time: 3290 ms
# Processing 29.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\29.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result29.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 4045x2353
# Required memory: 81 MB
# Allocating device memory...
# Allocated input memory: 27 MB
# Allocated blurred memory: 27 MB
# Allocated output memory: 27 MB
# Processing completed in 1362 ms using cuda method
#
# OhYESDADDY:
# Execution time: 1362 ms
# Processing 3.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\3.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result3.bmp sequential
# Output: Processing completed in 2137 ms using sequential method
#
# OhYESDADDY:
# Execution time: 2137 ms
# Processing 3.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\3.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result3.bmp omp
# Output: Processing completed in 192 ms using omp method
#
# OhYESDADDY:
# Execution time: 192 ms
# Processing 3.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\3.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result3.bmp mpi
# Output: Processing completed in 335 ms using mpi method
#
# OhYESDADDY:
# Execution time: 335 ms
# Processing 3.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\3.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result3.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 1200x800
# Required memory: 8 MB
# Allocating device memory...
# Allocated input memory: 2 MB
# Allocated blurred memory: 2 MB
# Allocated output memory: 2 MB
# Processing completed in 209 ms using cuda method
#
# OhYESDADDY:
# Execution time: 209 ms
# Processing 30.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\30.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result30.bmp sequential
# Output: Processing completed in 1258 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1258 ms
# Processing 30.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\30.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result30.bmp omp
# Output: Processing completed in 40 ms using omp method
#
# OhYESDADDY:
# Execution time: 40 ms
# Processing 30.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\30.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result30.bmp mpi
# Output: Processing completed in 78 ms using mpi method
#
# OhYESDADDY:
# Execution time: 78 ms
# Processing 30.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\30.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result30.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 620x350
# Required memory: 1 MB
# Allocating device memory...
# Allocated input memory: 0 MB
# Allocated blurred memory: 0 MB
# Allocated output memory: 0 MB
# Processing completed in 99 ms using cuda method
#
# OhYESDADDY:
# Execution time: 99 ms
# Processing 31.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\31.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result31.bmp sequential
# Output: Processing completed in 19250 ms using sequential method
#
# OhYESDADDY:
# Execution time: 19250 ms
# Processing 31.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\31.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result31.bmp omp
# Output: Processing completed in 2297 ms using omp method
#
# OhYESDADDY:
# Execution time: 2297 ms
# Processing 31.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\31.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result31.bmp mpi
# Output: Processing completed in 5111 ms using mpi method
#
# OhYESDADDY:
# Execution time: 5111 ms
# Processing 31.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\31.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result31.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 5120x2880
# Required memory: 126 MB
# Allocating device memory...
# Allocated input memory: 42 MB
# Allocated blurred memory: 42 MB
# Allocated output memory: 42 MB
# Processing completed in 2079 ms using cuda method
#
# OhYESDADDY:
# Execution time: 2079 ms
# Processing 32.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\32.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result32.bmp sequential
# Output: Processing completed in 2267 ms using sequential method
#
# OhYESDADDY:
# Execution time: 2267 ms
# Processing 32.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\32.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result32.bmp omp
# Output: Processing completed in 213 ms using omp method
#
# OhYESDADDY:
# Execution time: 213 ms
# Processing 32.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\32.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result32.bmp mpi
# Output: Processing completed in 385 ms using mpi method
#
# OhYESDADDY:
# Execution time: 385 ms
# Processing 32.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\32.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result32.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 1024x1024
# Required memory: 9 MB
# Allocating device memory...
# Allocated input memory: 3 MB
# Allocated blurred memory: 3 MB
# Allocated output memory: 3 MB
# Processing completed in 240 ms using cuda method
#
# OhYESDADDY:
# Execution time: 240 ms
# Processing 33.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\33.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result33.bmp sequential
# Output: Processing completed in 1813 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1813 ms
# Processing 33.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\33.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result33.bmp omp
# Output: Processing completed in 136 ms using omp method
#
# OhYESDADDY:
# Execution time: 136 ms
# Processing 33.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\33.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result33.bmp mpi
# Output: Processing completed in 241 ms using mpi method
#
# OhYESDADDY:
# Execution time: 241 ms
# Processing 33.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\33.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result33.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 1000x667
# Required memory: 5 MB
# Allocating device memory...
# Allocated input memory: 1 MB
# Allocated blurred memory: 1 MB
# Allocated output memory: 1 MB
# Processing completed in 177 ms using cuda method
#
# OhYESDADDY:
# Execution time: 177 ms
# Processing 34.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\34.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result34.bmp sequential
# Output: Processing completed in 4521 ms using sequential method
#
# OhYESDADDY:
# Execution time: 4521 ms
# Processing 34.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\34.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result34.bmp omp
# Output: Processing completed in 493 ms using omp method
#
# OhYESDADDY:
# Execution time: 493 ms
# Processing 34.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\34.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result34.bmp mpi
# Output: Processing completed in 1050 ms using mpi method
#
# OhYESDADDY:
# Execution time: 1050 ms
# Processing 34.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\34.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result34.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 2124x1413
# Required memory: 25 MB
# Allocating device memory...
# Allocated input memory: 8 MB
# Allocated blurred memory: 8 MB
# Allocated output memory: 8 MB
# Processing completed in 506 ms using cuda method
#
# OhYESDADDY:
# Execution time: 506 ms
# Processing 35.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\35.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result35.bmp sequential
# Output: Processing completed in 4795 ms using sequential method
#
# OhYESDADDY:
# Execution time: 4795 ms
# Processing 35.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\35.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result35.bmp omp
# Output: Processing completed in 518 ms using omp method
#
# OhYESDADDY:
# Execution time: 518 ms
# Processing 35.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\35.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result35.bmp mpi
# Output: Processing completed in 1121 ms using mpi method
#
# OhYESDADDY:
# Execution time: 1121 ms
# Processing 35.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\35.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result35.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 2201x1467
# Required memory: 27 MB
# Allocating device memory...
# Allocated input memory: 9 MB
# Allocated blurred memory: 9 MB
# Allocated output memory: 9 MB
# Processing completed in 512 ms using cuda method
#
# OhYESDADDY:
# Execution time: 512 ms
# Processing 36.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\36.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result36.bmp sequential
# Output: Processing completed in 7889 ms using sequential method
#
# OhYESDADDY:
# Execution time: 7889 ms
# Processing 36.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\36.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result36.bmp omp
# Output: Processing completed in 953 ms using omp method
#
# OhYESDADDY:
# Execution time: 953 ms
# Processing 36.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\36.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result36.bmp mpi
# Output: Processing completed in 2066 ms using mpi method
#
# OhYESDADDY:
# Execution time: 2066 ms
# Processing 36.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\36.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result36.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 3000x1990
# Required memory: 51 MB
# Allocating device memory...
# Allocated input memory: 17 MB
# Allocated blurred memory: 17 MB
# Allocated output memory: 17 MB
# Processing completed in 854 ms using cuda method
#
# OhYESDADDY:
# Execution time: 854 ms
# Processing 37.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\37.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result37.bmp sequential
# Output: Processing completed in 1246 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1246 ms
# Processing 37.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\37.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result37.bmp omp
# Output: Processing completed in 40 ms using omp method
#
# OhYESDADDY:
# Execution time: 40 ms
# Processing 37.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\37.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result37.bmp mpi
# Output: Processing completed in 70 ms using mpi method
#
# OhYESDADDY:
# Execution time: 70 ms
# Processing 37.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\37.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result37.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 550x366
# Required memory: 1 MB
# Allocating device memory...
# Allocated input memory: 0 MB
# Allocated blurred memory: 0 MB
# Allocated output memory: 0 MB
# Processing completed in 101 ms using cuda method
#
# OhYESDADDY:
# Execution time: 101 ms
# Processing 38.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\38.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result38.bmp sequential
# Output: Processing completed in 1214 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1214 ms
# Processing 38.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\38.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result38.bmp omp
# Output: Processing completed in 33 ms using omp method
#
# OhYESDADDY:
# Execution time: 33 ms
# Processing 38.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\38.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result38.bmp mpi
# Output: Processing completed in 59 ms using mpi method
#
# OhYESDADDY:
# Execution time: 59 ms
# Processing 38.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\38.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result38.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 500x333
# Required memory: 1 MB
# Allocating device memory...
# Allocated input memory: 0 MB
# Allocated blurred memory: 0 MB
# Allocated output memory: 0 MB
# Processing completed in 92 ms using cuda method
#
# OhYESDADDY:
# Execution time: 92 ms
# Processing 39.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\39.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result39.bmp sequential
# Output: Processing completed in 1062 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1062 ms
# Processing 39.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\39.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result39.bmp omp
# Output: Processing completed in 10 ms using omp method
#
# OhYESDADDY:
# Execution time: 10 ms
# Processing 39.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\39.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result39.bmp mpi
# Output: Processing completed in 17 ms using mpi method
#
# OhYESDADDY:
# Execution time: 17 ms
# Processing 39.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\39.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result39.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 318x159
# Required memory: 0 MB
# Allocating device memory...
# Allocated input memory: 0 MB
# Allocated blurred memory: 0 MB
# Allocated output memory: 0 MB
# Processing completed in 75 ms using cuda method
#
# OhYESDADDY:
# Execution time: 75 ms
# Processing 4.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\4.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result4.bmp sequential
# Output: Processing completed in 1025 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1025 ms
# Processing 4.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\4.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result4.bmp omp
# Output: Processing completed in 24 ms using omp method
#
# OhYESDADDY:
# Execution time: 24 ms
# Processing 4.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\4.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result4.bmp mpi
# Output: Processing completed in 6 ms using mpi method
#
# OhYESDADDY:
# Execution time: 6 ms
# Processing 4.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\4.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result4.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 128x128
# Required memory: 0 MB
# Allocating device memory...
# Allocated input memory: 0 MB
# Allocated blurred memory: 0 MB
# Allocated output memory: 0 MB
# Processing completed in 65 ms using cuda method
#
# OhYESDADDY:
# Execution time: 65 ms
# Processing 40.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\40.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result40.bmp sequential
# Output: Processing completed in 1365 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1365 ms
# Processing 40.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\40.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result40.bmp omp
# Output: Processing completed in 56 ms using omp method
#
# OhYESDADDY:
# Execution time: 56 ms
# ...
# Total global memory: 4095 MB
# Processing image of size: 612x354
# Required memory: 1 MB
# Allocating device memory...
# Allocated input memory: 0 MB
# Allocated blurred memory: 0 MB
# Allocated output memory: 0 MB
# Processing completed in 119 ms using cuda method
#
# OhYESDADDY:
# Execution time: 119 ms
# Processing 46.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\46.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result46.bmp sequential
# Output: Processing completed in 1296 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1296 ms
# Processing 46.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\46.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result46.bmp omp
# Output: Processing completed in 48 ms using omp method
#
# OhYESDADDY:
# Execution time: 48 ms
# Processing 46.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\46.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result46.bmp mpi
# Output: Processing completed in 87 ms using mpi method
#
# OhYESDADDY:
# Execution time: 87 ms
# Processing 46.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\46.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result46.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 612x408
# Required memory: 2 MB
# Allocating device memory...
# Allocated input memory: 0 MB
# Allocated blurred memory: 0 MB
# Allocated output memory: 0 MB
# Processing completed in 101 ms using cuda method
#
# OhYESDADDY:
# Execution time: 101 ms
# Processing 47.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\47.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result47.bmp sequential
# Output: Processing completed in 3944 ms using sequential method
#
# OhYESDADDY:
# Execution time: 3944 ms
# Processing 47.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\47.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result47.bmp omp
# Output: Processing completed in 426 ms using omp method
#
# OhYESDADDY:
# Execution time: 426 ms
# Processing 47.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\47.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result47.bmp mpi
# Output: Processing completed in 903 ms using mpi method
#
# OhYESDADDY:
# Execution time: 903 ms
# Processing 47.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\47.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result47.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 1920x1281
# Required memory: 21 MB
# Allocating device memory...
# Allocated input memory: 7 MB
# Allocated blurred memory: 7 MB
# Allocated output memory: 7 MB
# Processing completed in 461 ms using cuda method
#
# OhYESDADDY:
# Execution time: 461 ms
# Processing 48.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\48.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result48.bmp sequential
# Output: Processing completed in 1264 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1264 ms
# Processing 48.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\48.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result48.bmp omp
# Output: Processing completed in 41 ms using omp method
#
# OhYESDADDY:
# Execution time: 41 ms
# Processing 48.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\48.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result48.bmp mpi
# Output: Processing completed in 76 ms using mpi method
#
# OhYESDADDY:
# Execution time: 76 ms
# Processing 48.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\48.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result48.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 621x350
# Required memory: 1 MB
# Allocating device memory...
# Allocated input memory: 0 MB
# Allocated blurred memory: 0 MB
# Allocated output memory: 0 MB
# Processing completed in 97 ms using cuda method
#
# OhYESDADDY:
# Execution time: 97 ms
# Processing 49.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\49.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result49.bmp sequential
# Output: Processing completed in 1929 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1929 ms
# Processing 49.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\49.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result49.bmp omp
# Output: Processing completed in 156 ms using omp method
#
# OhYESDADDY:
# Execution time: 156 ms
# Processing 49.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\49.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result49.bmp mpi
# Output: Processing completed in 265 ms using mpi method
#
# OhYESDADDY:
# Execution time: 265 ms
# Processing 49.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\49.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result49.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 1125x675
# Required memory: 6 MB
# Allocating device memory...
# Allocated input memory: 2 MB
# Allocated blurred memory: 2 MB
# Allocated output memory: 2 MB
# Processing completed in 189 ms using cuda method
#
# OhYESDADDY:
# Execution time: 189 ms
# Processing 5.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\5.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result5.bmp sequential
# Output: Processing completed in 1637 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1637 ms
# Processing 5.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\5.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result5.bmp omp
# Output: Processing completed in 104 ms using omp method
#
# OhYESDADDY:
# Execution time: 104 ms
# Processing 5.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\5.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result5.bmp mpi
# Output: Processing completed in 185 ms using mpi method
#
# OhYESDADDY:
# Execution time: 185 ms
# Processing 5.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\5.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result5.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 976x549
# Required memory: 4 MB
# Allocating device memory...
# Allocated input memory: 1 MB
# Allocated blurred memory: 1 MB
# Allocated output memory: 1 MB
# Processing completed in 139 ms using cuda method
#
# OhYESDADDY:
# Execution time: 139 ms
# Processing 50.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\50.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result50.bmp sequential
# Output: Processing completed in 1812 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1812 ms
# Processing 50.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\50.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result50.bmp omp
# Output: Processing completed in 127 ms using omp method
#
# OhYESDADDY:
# Execution time: 127 ms
# Processing 50.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\50.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result50.bmp mpi
# Output: Processing completed in 242 ms using mpi method
#
# OhYESDADDY:
# Execution time: 242 ms
# Processing 50.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\50.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result50.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 1080x635
# Required memory: 5 MB
# Allocating device memory...
# Allocated input memory: 1 MB
# Allocated blurred memory: 1 MB
# Allocated output memory: 1 MB
# Processing completed in 173 ms using cuda method
#
# OhYESDADDY:
# Execution time: 173 ms
# Processing 6.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\6.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result6.bmp sequential
# Output: Processing completed in 1778 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1778 ms
# Processing 6.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\6.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result6.bmp omp
# Output: Processing completed in 130 ms using omp method
#
# OhYESDADDY:
# Execution time: 130 ms
# Processing 6.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\6.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result6.bmp mpi
# Output: Processing completed in 233 ms using mpi method
#
# OhYESDADDY:
# Execution time: 233 ms
# Processing 6.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\6.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result6.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 1180x553
# Required memory: 5 MB
# Allocating device memory...
# Allocated input memory: 1 MB
# Allocated blurred memory: 1 MB
# Allocated output memory: 1 MB
# Processing completed in 171 ms using cuda method
#
# OhYESDADDY:
# Execution time: 171 ms
# Processing 8.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\8.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result8.bmp sequential
# Output: Processing completed in 3108 ms using sequential method
#
# OhYESDADDY:
# Execution time: 3108 ms
# Processing 8.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\8.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result8.bmp omp
# Output: Processing completed in 339 ms using omp method
#
# OhYESDADDY:
# Execution time: 339 ms
# Processing 8.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\8.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result8.bmp mpi
# Output: Processing completed in 620 ms using mpi method
#
# OhYESDADDY:
# Execution time: 620 ms
# Processing 8.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\8.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result8.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 1599x1066
# Required memory: 14 MB
# Allocating device memory...
# Allocated input memory: 4 MB
# Allocated blurred memory: 4 MB
# Allocated output memory: 4 MB
# Processing completed in 332 ms using cuda method
#
# OhYESDADDY:
# Execution time: 332 ms
# Processing 9.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\9.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result9.bmp sequential
# Output: Processing completed in 1806 ms using sequential method
#
# OhYESDADDY:
# Execution time: 1806 ms
# Processing 9.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\9.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result9.bmp omp
# Output: Processing completed in 145 ms using omp method
#
# OhYESDADDY:
# Execution time: 145 ms
# Processing 9.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\9.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result9.bmp mpi
# Output: Processing completed in 233 ms using mpi method
#
# OhYESDADDY:
# Execution time: 233 ms
# Processing 9.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\9.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Result9.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 960x682
# Required memory: 5 MB
# Allocating device memory...
# Allocated input memory: 1 MB
# Allocated blurred memory: 1 MB
# Allocated output memory: 1 MB
# Processing completed in 161 ms using cuda method
#
# OhYESDADDY:
# Execution time: 161 ms
# Processing sample1.bmp (24-bit) using sequential method...
# Command: ./sequential.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\sample1.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Resultsample1.bmp sequential
# Output: Processing completed in 5974 ms using sequential method
#
# OhYESDADDY:
# Execution time: 5974 ms
# Processing sample1.bmp (24-bit) using omp method...
# Command: ./omp_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\sample1.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Resultsample1.bmp omp
# Output: Processing completed in 735 ms using omp method
#
# OhYESDADDY:
# Execution time: 735 ms
# Processing sample1.bmp (24-bit) using mpi method...
# Command: ./mpi_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\sample1.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Resultsample1.bmp mpi
# Output: Processing completed in 1485 ms using mpi method
#
# OhYESDADDY:
# Execution time: 1485 ms
# Processing sample1.bmp (24-bit) using cuda method...
# Command: ./cuda_version.exe c:\Users\user\Desktop\FInal DSPC\New folder\input\sample1.bmp c:\Users\user\Desktop\FInal DSPC\New folder\output\Resultsample1.bmp cuda
# Output: Using CUDA device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total global memory: 4095 MB
# Processing image of size: 2048x2048
# Required memory: 36 MB
# Allocating device memory...
# Allocated input memory: 12 MB
# Allocated blurred memory: 12 MB
# Allocated output memory: 12 MB
# Processing completed in 670 ms using cuda method
#
# OhYESDADDY:
# Execution time: 670 ms
#
# Performance Statistics:
# ==================================================
#
# Detailed Statistics:
#            Time (ms)
#                count     mean  median      std   min    max
# Method
# CUDA              47   363.89   171.0   471.32    65   2079
# MPI               47   735.26   238.0  1192.78     6   5111
# OpenMP            47   349.64   127.0   535.29    10   2297
# Sequential        47  3500.11  1805.0  4122.98  1025  19250
#
# Speedup Analysis:
# ==================================================
#
# Size Category: Very Large (>10MB)
# OpenMP: 8.27x speedup
# MPI: 3.78x speedup
# CUDA: 9.00x speedup
#
# Size Category: Small (<1MB)
# OpenMP: 31.79x speedup
# MPI: 17.56x speedup
# CUDA: 12.74x speedup
#
# Size Category: Medium (1-5MB)
# OpenMP: 11.90x speedup
# MPI: 6.51x speedup
# CUDA: 10.18x speedup
#
# Size Category: Large (5-10MB)
# OpenMP: 9.23x speedup
# MPI: 4.31x speedup
# CUDA: 8.97x speedup
#
# Results and statistics saved to:
# - performance_results.csv
# - performance_statistics.csv
# - boxplot_comparison.png
# - violin_comparison.png
# - size_vs_time.png
# - average_times.png
